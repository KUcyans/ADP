# %% [markdown]
# ### FWHM = 4 (unit : pixels)
# ### Choose the proper aperture size
# * FWHM : 4 pixels
# * pixel scale of the seeing = 0.157 arcsec/sec (per unbinned pixel)
#     ← can calculate the values in arcsec
# * use the data of standard stars in STANDARD
# *
# ## Important thing! The vertical line of the image comes first when indexing the 2D array. The horizontal line comes later.
# > ###  So the coordinate may be written in a form of $(vertical, horizontal)$
# * use of FWHM value for photometry
#     * to see how dispers the object is?
#     * to confine the object in unit of pixels

# %%
import dfitspy
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
from scipy import ndimage
from photutils.centroids import centroid_quadratic
from photutils.profiles import RadialProfile
from photutils.aperture import CircularAperture
import photutils.aperture as aptr
from scipy.misc import derivative

dirEx3 = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/'
dirSTD = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/STANDARD'
dirErr = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/PSError'

filters =['V#641','R#642','B#639']
fileNames = {'V#641':'EFOSC.2001-01-03T08:55:18.187.fits',
            'R#642':'EFOSC.2001-01-03T08:56:03.899.fits',
            'B#639':'EFOSC.2001-01-03T08:54:27.270.fits'}

# PG 1323-086
# PG 1323-086 B
# PG 1323-086 C
LandoltBands = ['V', 'B-V', 'U-B', 'V-R', 'R-I', 'V-I']
LandoltBand = [[13.481,	-0.140,	-0.681,	-0.048,	-0.078,	-0.127],
                [13.406,	0.761,	0.265,	0.426,	0.407,	0.833],
                [14.003,	0.707,	0.245,	0.395,	0.363,	0.759]]

# PG 1323-086		13.481	-0.140	-0.681	-0.048	-0.078	-0.127
# PG 1323-086 B		13.406	0.761	0.265	0.426	0.407	0.833
# PG 1323-086 C		14.003	0.707	0.245	0.395	0.363	0.759

#combination of 0, B, C with V, R, B
LandoltMag = np.zeros((3,3), dtype = 'f')
for i in range(len(LandoltBand)):
    LandoltMag[i][0] = LandoltBand[i][0]
    LandoltMag[i][1] = LandoltBand[i][0] - LandoltBand[i][3]
    LandoltMag[i][2] = LandoltBand[i][0] + LandoltBand[i][1]

##========================================= check the headers of the fitses of STANDARD stars
os.chdir(dirSTD)
fitsFiles = []
for fitsFile in os.listdir(dirSTD):
    fitsFiles.append(fitsFile)
keys = ['OBJECT', 'NAXIS1', 'NAXIS2', 'EXPTIME', 'HIERARCH ESO INS FILT1 NAME']
stdFiles = dfitspy.dfitsort(fitsFiles, keys)
dfitspy.dfitsort_view(stdFiles)

##========================================= get the data or the header of fits files in the directory
def getFitsData(fileName):
    fitsStdData = fits.getdata(fileName, header = False, dtype = 'f')
    stdData = fitsStdData[100:900,100:900]
    return stdData

def getFitsHeader(fileName):
    return fits.getheader(fileName)

##========================================= get var data of processed science
def getPSError(filter, type):
    previousDir = os.getcwd()
    pSError = [ [0]*800 for i in range(800) ]
    os.chdir(dirErr)
    fileName = filter+type+'.processed.error'
    if os.path.exists(fileName):
        with open(fileName, "r") as file:
            ##load data from file
            listOfLines = file.read().splitlines()   #list of strings
            for i in range(len(listOfLines)):
                line = listOfLines[i] #list of string, delimiter = ','
                listOfValues = line.split(',')
                for j in range(len(listOfValues)):
                    value = listOfValues[j]
                    if not value =='':
                        pSError[i][j] = float(value)
    os.chdir(previousDir)
    return pSError

##========================================= get RadialProfile
def getRadialProfile(coo, stdData):
    xycen = centroid_quadratic(stdData, xpeak = coo[0], ypeak = coo[1], fit_boxsize = 11, search_boxsize = 11)
    edge_radii = np.arange(25)
    rp = RadialProfile(stdData, xycen, edge_radii, mask=None)
    return rp
    
##========================================= get FWHM
def getFWHM(coo, stdData):
    return getRadialProfile(coo, stdData).gaussian_fwhm

##========================================= aperture factors are multiplied to the gaussian FWHM
# apertureFactor = np.arange(0.01, 2, 0.1, dtype ='f')
apertureFactor = np.arange(0.5, 4, 0.5, dtype ='f')

##========================================= get magnitudes wrt the aperture factors
def getMagnitude(coo, stdData, expTime, errorData):
    magnitudes = []
    for f in apertureFactor:
        rp = getRadialProfile(coo, stdData)
        aperture = CircularAperture(coo, f * rp.gaussian_fwhm)
        phot = aptr.aperture_photometry(stdData, aperture, method = 'subpixel', error = errorData, subpixels = 5)
        mag = float(-2.5*(np.log10(phot['aperture_sum']/expTime)) + 25)
        print(phot)
        magnitudes.append(mag)
    return magnitudes
    
##========================================= plotting function
def plotApertureMagnitude(coo, stdData, errorData, expTime, title, ax=None):
    if ax is None:
        ax = plt.gca()
    mag = getMagnitude(coo, stdData, expTime, errorData)
    plot = ax.plot(apertureFactor, mag, '.')
    ax.set_title(title)
    ax.set_xlim(0,2)
    ax.set_ylim(15.5,11.5)
    return plot
    
##========================================= choosing aperture : where the second derivative is the greates
def chooseProperAperture(coo, stdData, expTime, errorData):
    rp = getRadialProfile(coo, stdData)
    magnitude = getMagnitude(coo, stdData, expTime, errorData)
    change = []
    changeChange = []
    changeChangeRatio = []
    for i in range(len(apertureFactor)-1):
        # print(apertureFactor[i], ' : ' ,np.abs(magnitude[i+1]-magnitude[i]))
        change.append(np.abs(magnitude[i+1]-magnitude[i]))
    for i in range(len(change)-1):
        changeChange.append(np.abs(change[i+1]-change[i]))
        # print(apertureFactor[i], ' : ' ,np.abs(changeChange[i+1]-changeChange[i]))
    for i in range(len(changeChange)-1):
        changeChangeRatio.append(np.abs((changeChange[i+1]-changeChange[i])/changeChange[i]))
    maxF = max(changeChangeRatio)
    imaxF = changeChangeRatio.index(max(changeChangeRatio))
    properAperture = apertureFactor[imaxF] * rp.gaussian_fwhm
    print('factor : ', apertureFactor[imaxF])
    print('gaussianfwhm : ',rp.gaussian_fwhm)
    print()
    return properAperture
    
##========================================= extract fits data of the fitses of STANDARD stars
fig, axs = plt.subplots(1,3,figsize = (15,15))
fig_a, axs_a = plt.subplots(3,3,figsize = (10,10))

for i in range(len(os.listdir(dirSTD))):
    fitsHeader = getFitsHeader(os.listdir(dirSTD)[i])
    stdData  = getFitsData(os.listdir(dirSTD)[i])
    expTime = fitsHeader['EXPTIME']
    errorData = getPSError(filters[i],'SkyFlat')
    im = axs[i].imshow(stdData, vmin = np.mean(stdData) - np.std(stdData), vmax = np.mean(stdData) + np.std(stdData), cmap = 'magma')
    axs[i].set_title('PG-1323-086 '+filters[i])
    fig.colorbar(im, ax = axs[i],fraction=0.046, pad=0.04)
    
    print('--------------------------------',filters[i],'--------------------------------')
    # PG-1323-086
    coo = np.array([733,451])
    plotApertureMagnitude(coo, stdData, errorData, expTime, 'PG-1323-086 , '+filters[i], axs_a[i][0])
    print('recom.Apeture for  : ',chooseProperAperture(coo, stdData, expTime, errorData))
    # PG-1323-086 B
    cooB = np.array([204,158])
    plotApertureMagnitude(cooB, stdData, errorData, expTime, 'PG-1323-086 B, '+filters[i], axs_a[i][1])
    print('recom.Apeture for B : ',chooseProperAperture(cooB, stdData, expTime, errorData))
    # PG-1323-086 C
    cooC = np.array([231,589])
    plotApertureMagnitude(cooC, stdData, errorData, expTime, 'PG-1323-086 C, '+filters[i], axs_a[i][2])
    print('recom.Apeture for C : ',chooseProperAperture(cooC, stdData, expTime, errorData))

plt.show()
# Out:
#              filename             	EXPTIME	HIERARCH ESO INS FILT1 NAME	NAXIS1	NAXIS2	       OBJECT
# ----------------------------------	-------	---------------------------	------	------	--------------------
# EFOSC.2001-01-03T08:55:18.187.fits	4.9968 	           V#641           	 1030 	 1030 	PG-1323-086-phot-std
# EFOSC.2001-01-03T08:56:03.899.fits	4.9969 	           R#642           	 1030 	 1030 	PG-1323-086-phot-std
# EFOSC.2001-01-03T08:54:27.270.fits	9.9968 	           B#639           	 1030 	 1030 	PG-1323-086-phot-std
# -------------------------------- V#641 --------------------------------
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   733.0   451.0      1118.16       79.5108212
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     14536.08 286.6803427908492
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     48642.72 550.1295841307443
#  id xcenter ycenter    aperture_sum   aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ----------------
#   1   733.0   451.0 99695.68000000001 830.904650446797
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    161110.32 1084.6072716497908
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    212426.84 1354.480485303303
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    265617.52 1631.9810825418135
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   733.0   451.0 311902.1599999999 1904.7869744364891
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 346397.95999999996 2187.0379729051583
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 376254.99999999994 2457.176508319426
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    399124.52 2734.8887389495717
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 418672.51999999996 3009.3529716445632
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    436478.92 3284.0144095954684
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    449938.04 3535.0953195294437
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0     464165.4 3811.4749726336504
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0     476864.0 4082.9344938008485
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    488569.48 4342.087680398213
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    500963.72 4615.605031826675
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 513046.00000000006 4881.1284081305685
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     525486.2 5148.246767241977
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   733.0   451.0      1118.16       79.5108212
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     14536.08 286.6803427908492
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     48642.72 550.1295841307443
#  id xcenter ycenter    aperture_sum   aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ----------------
#   1   733.0   451.0 99695.68000000001 830.904650446797
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    161110.32 1084.6072716497908
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    212426.84 1354.480485303303
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    265617.52 1631.9810825418135
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   733.0   451.0 311902.1599999999 1904.7869744364891
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 346397.95999999996 2187.0379729051583
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 376254.99999999994 2457.176508319426
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    399124.52 2734.8887389495717
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 418672.51999999996 3009.3529716445632
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    436478.92 3284.0144095954684
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    449938.04 3535.0953195294437
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0     464165.4 3811.4749726336504
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0     476864.0 4082.9344938008485
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    488569.48 4342.087680398213
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    500963.72 4615.605031826675
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 513046.00000000006 4881.1284081305685
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     525486.2 5148.246767241977
# factor :  1.21
# gaussianfwhm :  3.879847608681756
#
# recom.Apeture for  :  4.694615754509365
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0        575.0       77.6976734
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0       7475.0 280.14294542795443
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 28492.760000000002 555.1732622673727
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     63257.24 839.1044442246947
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 111697.88000000002 1122.262134405509
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    161308.92 1380.7941714542337
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    222306.96 1666.5365186760355
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    278436.68 1929.7401441088343
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   204.0   158.0 323893.6000000001 2193.7590487499833
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    369653.08 2465.5348019149956
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   204.0   158.0 404908.44000000006 2748.80797508646
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   204.0   158.0 431001.12000000005 3011.45083645683
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    453755.76 3273.8132295660093
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    471771.36 3545.5783388043737
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 487271.16000000003 3811.824855865022
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 501940.07999999996 4077.7672428465053
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    514693.76 4336.952526086233
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    528390.88 4616.855760510411
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     540744.8 4880.749082849097
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    553739.72 5156.365540856632
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0        575.0       77.6976734
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0       7475.0 280.14294542795443
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 28492.760000000002 555.1732622673727
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     63257.24 839.1044442246947
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 111697.88000000002 1122.262134405509
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    161308.92 1380.7941714542337
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    222306.96 1666.5365186760355
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    278436.68 1929.7401441088343
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   204.0   158.0 323893.6000000001 2193.7590487499833
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    369653.08 2465.5348019149956
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   204.0   158.0 404908.44000000006 2748.80797508646
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   204.0   158.0 431001.12000000005 3011.45083645683
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    453755.76 3273.8132295660093
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    471771.36 3545.5783388043737
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 487271.16000000003 3811.824855865022
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 501940.07999999996 4077.7672428465053
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    514693.76 4336.952526086233
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    528390.88 4616.855760510411
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     540744.8 4880.749082849097
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    553739.72 5156.365540856632
# factor :  1.51
# gaussianfwhm :  3.826688570352982
#
# recom.Apeture for B :  5.778299704738857
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0       417.64       75.0488204
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 3758.7599999999998 225.14646119999998
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0      18383.0 508.85224295753824
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     38620.36 750.1845264082034
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0     69015.56 1012.1063990346888
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 100332.99999999999 1263.963425197556
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    129027.76 1490.9124841554567
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    161569.12 1727.931293503733
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0    188698.24 1971.66475767977
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    215500.32 2230.406704719261
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 238315.39999999997 2471.8081807896037
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    256795.76 2721.252048879774
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 272620.12000000005 2956.8897706147864
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 287849.95999999996 3206.091142793122
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 300590.80000000005 3452.927491312951
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    312202.76 3687.357228782334
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0     323948.8 3944.5845488263826
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    334665.36 4187.551470075684
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     345365.8 4427.126568999971
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0    356597.44 4676.55066183184
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0       417.64       75.0488204
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 3758.7599999999998 225.14646119999998
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0      18383.0 508.85224295753824
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     38620.36 750.1845264082034
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0     69015.56 1012.1063990346888
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 100332.99999999999 1263.963425197556
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    129027.76 1490.9124841554567
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    161569.12 1727.931293503733
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0    188698.24 1971.66475767977
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    215500.32 2230.406704719261
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 238315.39999999997 2471.8081807896037
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    256795.76 2721.252048879774
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 272620.12000000005 2956.8897706147864
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 287849.95999999996 3206.091142793122
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 300590.80000000005 3452.927491312951
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    312202.76 3687.357228782334
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0     323948.8 3944.5845488263826
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    334665.36 4187.551470075684
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     345365.8 4427.126568999971
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0    356597.44 4676.55066183184
# factor :  1.41
# gaussianfwhm :  3.6355515839604124
#
# recom.Apeture for C :  5.126127612034556
# -------------------------------- R#642 --------------------------------
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   733.0   451.0       676.76       90.5100486
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0     14211.96 414.76914886363187
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     39089.04 698.1310999496366
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     75274.04 974.5528274900856
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    131431.28 1304.350065667167
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 186199.31999999998 1611.550552059334
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 246536.75999999998 1925.9761857461806
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     296628.4 2246.464690752133
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    337137.76 2547.298803119554
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    375831.16 2871.1567609493413
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 400417.68000000005 3157.8713639051716
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 424256.88000000006 3475.804256985584
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 441399.79999999993 3781.7835289132827
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   733.0   451.0 456593.9200000001 4097.368265315162
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    470836.88 4415.634674546709
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 483168.83999999997 4720.497297320706
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   733.0   451.0 496025.92000000004 5039.42989698198
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 507844.83999999997 5345.050853767125
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    520116.52 5657.945676203995
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     532270.0 5960.560682213375
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   733.0   451.0       676.76       90.5100486
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0     14211.96 414.76914886363187
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     39089.04 698.1310999496366
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     75274.04 974.5528274900856
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    131431.28 1304.350065667167
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 186199.31999999998 1611.550552059334
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 246536.75999999998 1925.9761857461806
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     296628.4 2246.464690752133
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    337137.76 2547.298803119554
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   733.0   451.0    375831.16 2871.1567609493413
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 400417.68000000005 3157.8713639051716
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 424256.88000000006 3475.804256985584
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   733.0   451.0 441399.79999999993 3781.7835289132827
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   733.0   451.0 456593.9200000001 4097.368265315162
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    470836.88 4415.634674546709
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 483168.83999999997 4720.497297320706
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   733.0   451.0 496025.92000000004 5039.42989698198
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   733.0   451.0 507844.83999999997 5345.050853767125
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0    520116.52 5657.945676203995
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   733.0   451.0     532270.0 5960.560682213375
# factor :  1.41
# gaussianfwhm :  4.069216233004723
#
# recom.Apeture for  :  5.737594752711914
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0       649.64       89.6719906
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0      8445.32 323.31696008122486
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 28851.199999999997 600.5755669161422
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0      67776.8 933.7127345430222
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 113554.99999999999 1216.0788605728121
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 173704.71999999997 1526.7047270359283
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     240114.8 1825.237158101814
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 311484.11999999994 2114.7365798702454
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 385553.4800000001 2415.095629273082
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 455825.99999999994 2687.4602249053673
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 516779.00000000006 2961.834185889079
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    570966.16 3246.3304021065487
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    628763.12 3558.974035227133
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    664346.56 3855.7503631915956
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    694751.36 4146.199801628373
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    721405.56 4442.793982273503
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     741199.8 4741.712818390953
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   204.0   158.0 759510.7200000001 5041.9669229977935
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     775346.6 5338.749395866354
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 789133.7200000001 5616.727805133049
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0       649.64       89.6719906
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0      8445.32 323.31696008122486
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 28851.199999999997 600.5755669161422
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0      67776.8 933.7127345430222
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 113554.99999999999 1216.0788605728121
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 173704.71999999997 1526.7047270359283
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     240114.8 1825.237158101814
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 311484.11999999994 2114.7365798702454
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 385553.4800000001 2415.095629273082
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   204.0   158.0 455825.99999999994 2687.4602249053673
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 516779.00000000006 2961.834185889079
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    570966.16 3246.3304021065487
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    628763.12 3558.974035227133
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    664346.56 3855.7503631915956
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    694751.36 4146.199801628373
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    721405.56 4442.793982273503
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     741199.8 4741.712818390953
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   204.0   158.0 759510.7200000001 5041.9669229977935
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     775346.6 5338.749395866354
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 789133.7200000001 5616.727805133049
# factor :  1.01
# gaussianfwhm :  3.7800896988812953
#
# recom.Apeture for B :  3.8178905598203636
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0        564.6       92.9138272
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0       7339.8 335.0055681692007
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     29958.52 680.4895437560396
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     60255.72 977.7381356680339
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 104070.59999999999 1308.6285011616674
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     148136.2 1612.243115348366
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 195972.84000000003 1906.2764333539037
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 243161.63999999998 2226.5567454265283
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    284811.72 2526.3834958587045
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 323233.60000000003 2827.194843552375
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 354719.27999999997 3141.4659818826703
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    381925.12 3455.189781728265
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    403316.64 3772.373630483537
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 420331.00000000006 4085.5127104787384
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    435829.88 4399.529603661949
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 449136.24000000005 4707.813173710912
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   231.0   589.0 461574.39999999997 5005.46851369371
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 474528.43999999994 5331.742608162031
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
# ...
#   1   204.0   158.0     103170.0 1305.291873497116
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     154778.0 1617.560182282104
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 211515.27999999997 1943.549753419667
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    270656.52 2262.815918062168
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    321866.48 2558.2369525187682
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    376283.48 2882.620534341739
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    424032.48 3199.107721969673
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     470833.0 3536.139096514197
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    510681.36 3844.340169775297
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 551968.6399999999 4181.080185995189
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0    588730.48 4490.64054811897
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     627639.4 4820.481629786529
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    663877.28 5124.713764604871
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    702111.24 5440.2043117991225
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    741593.76 5760.1694041342525
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 782711.6000000001 6078.767800183673
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0       320.48       74.3437476
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0      6730.08 340.6858508236915
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ----------------
#   1   204.0   158.0 28823.160000000003 685.081545748084
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 60101.399999999994 982.9848971210882
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     103170.0 1305.291873497116
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     154778.0 1617.560182282104
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   204.0   158.0 211515.27999999997 1943.549753419667
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    270656.52 2262.815918062168
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    321866.48 2558.2369525187682
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    376283.48 2882.620534341739
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    424032.48 3199.107721969673
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     470833.0 3536.139096514197
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    510681.36 3844.340169775297
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 551968.6399999999 4181.080185995189
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   204.0   158.0    588730.48 4490.64054811897
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0     627639.4 4820.481629786529
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   204.0   158.0    663877.28 5124.713764604871
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    702111.24 5440.2043117991225
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   204.0   158.0    741593.76 5760.1694041342525
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- -----------------
#   1   204.0   158.0 782711.6000000001 6078.767800183673
# factor :  1.3100001
# gaussianfwhm :  4.929984155109822
#
# recom.Apeture for B :  6.45827954879782
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0       109.04        75.316144
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0       2726.0        376.58072
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     11549.72 730.4458938284528
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 27567.559999999994 1104.6999104856534
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0     49213.28 1440.0074766898035
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   231.0   589.0 81695.92000000001 1816.2207681267678
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 119720.31999999998 2163.102454841083
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 160030.71999999997 2480.827440174109
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 208001.59999999998 2847.0414955771103
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    255219.88 3199.537730959262
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    300001.04 3543.5060239311933
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    343770.92 3894.0546453747497
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    387024.12 4255.0283592774185
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0     426652.4 4591.58037006774
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    468704.56 4947.366921335946
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    510311.84 5301.535813831727
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    549629.12 5629.895302565754
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    594100.04 5996.961983174565
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0     638601.0 6349.71032682958
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    683879.44 6692.921103736926
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0       109.04        75.316144
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0       2726.0        376.58072
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0     11549.72 730.4458938284528
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 27567.559999999994 1104.6999104856534
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0     49213.28 1440.0074766898035
#  id xcenter ycenter    aperture_sum    aperture_sum_err
#       pix     pix
# --- ------- ------- ----------------- ------------------
#   1   231.0   589.0 81695.92000000001 1816.2207681267678
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 119720.31999999998 2163.102454841083
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ -----------------
#   1   231.0   589.0 160030.71999999997 2480.827440174109
#  id xcenter ycenter    aperture_sum     aperture_sum_err
#       pix     pix
# --- ------- ------- ------------------ ------------------
#   1   231.0   589.0 208001.59999999998 2847.0414955771103
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    255219.88 3199.537730959262
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    300001.04 3543.5060239311933
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    343770.92 3894.0546453747497
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ------------------
#   1   231.0   589.0    387024.12 4255.0283592774185
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0     426652.4 4591.58037006774
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    468704.56 4947.366921335946
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    510311.84 5301.535813831727
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    549629.12 5629.895302565754
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    594100.04 5996.961983174565
#  id xcenter ycenter aperture_sum aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ ----------------
#   1   231.0   589.0     638601.0 6349.71032682958
#  id xcenter ycenter aperture_sum  aperture_sum_err
#       pix     pix
# --- ------- ------- ------------ -----------------
#   1   231.0   589.0    683879.44 6692.921103736926
# factor :  1.21
# gaussianfwhm :  5.339819863200744
#
# recom.Apeture for C :  6.461182238170863

# %% [markdown]
# ### Ex4 Background Substraction with annulus
# #### let the proper aperture 5.7 pixels(previous Ex)

# %%
import astropy.io.fits as fits
import dfitspy
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
from scipy import ndimage
from photutils.centroids import centroid_quadratic
from photutils.profiles import RadialProfile
from photutils.aperture import CircularAperture
import photutils.aperture as aptr
from photutils.aperture import CircularAnnulus
from astropy.stats import sigma_clipped_stats
##========================================= dirs
dirEx3 = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/'
dirSTD = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/STANDARD'
dirErr = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/PSError'
dirPC = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/PhotoCalibration'
##========================================= file names 
filters =['V#641','R#642','B#639']
fileNames = {'V#641':'EFOSC.2001-01-03T08:55:18.187.fits',
             'R#642':'EFOSC.2001-01-03T08:56:03.899.fits',
             'B#639':'EFOSC.2001-01-03T08:54:27.270.fits'}

##========================================= standard stars and its centres
stdName = ['PG-1323-086', 'PG-1323-086 B', 'PG-1323-086 C']
coos = [np.array([733,451]),np.array([204,158]),np.array([231,589])]
##========================================= standard stars and its centres
os.chdir(dirSTD)
fitsFiles = [m for m in os.listdir() if m.endswith('.fits')]
print(fitsFiles)

keys = ['OBJECT', 'EXPTIME', 'HIERARCH ESO INS FILT1 NAME']
stdFiles = dfitspy.dfitsort(fitsFiles, keys)
dfitspy.dfitsort_view(stdFiles)
    
##========================================= get data of fits files in the directory
def getFitsData(fileName):
    fitsStdData = fits.getdata(fileName, header = False, dtype = 'f')
    stdData = fitsStdData[100:900,100:900]
    return stdData
##========================================= get header of fits files in the directory
def getFitsHeader(fileName):
    return fits.getheader(fileName)
##========================================= get the error data from science image
def getPSError(filter, type):
    previousDir = os.getcwd()
    pSError = [ [0]*800 for i in range(800) ]
    os.chdir(dirErr)
    fileName = filter+type+'.processed.error'
    if os.path.exists(fileName):
        with open(fileName, "r") as file:
            ##load data from file
            listOfLines = file.read().splitlines()   #list of strings
            for i in range(len(listOfLines)):
                line = listOfLines[i] #list of string, delimiter = ','
                listOfValues = line.split(',')
                for j in range(len(listOfValues)):
                    value = listOfValues[j]
                    if not value =='':
                        pSError[i][j] = float(value)
    os.chdir(previousDir)
    return pSError
##========================================= rough locations for the standard stars and their names
coos = [np.array([733,451]),np.array([204,158]),np.array([231,589])]
stdName = ['PG-1323-086  ', 'PG-1323-086 B', 'PG-1323-086 C']
apertureFactor = np.arange(0.5, 4.5, 0.5, dtype ='f')
##========================================= 
'''
Statistics is a data type that takes data from fits
an Statistics object provides calculated values such as FWHM, circular aperture, magnitude, and magnitude error

'''
#==================================================================
class Statistics:
    #=======================CTOR===================================\
    def __init__(self,  coo, stdData, errorData, expTime, f):
        self.prevDir = os.getcwd()
        os.chdir(dirPC)
        self.coo = coo
        self.stdData = stdData
        self.errorData = errorData
        self.expTime = expTime
        self.f = f
        self.__setRadialProfile()
        self.FWHM = self.rp.gaussian_fwhm
        self.__setRadii()
        self.__setApertureCircle()
        self.__setApertureAnnulus()
        self.__setAnnulusBackground()
        self.__setCcdMag()
        self.__setMagErr()
    #=======================DTOR===================================\   
    def __del__(self):
        os.chdir(self.prevDir)
    #==========================================================private methods
    def __setRadialProfile(self):
        xycen = centroid_quadratic(self.stdData, xpeak = self.coo[0], ypeak = self.coo[1], fit_boxsize = 11, search_boxsize = 11)
        edge_radii = np.arange(4)
        rp = RadialProfile(self.stdData, xycen, edge_radii, mask=None)
        self.rp = rp
    def __setApertureCircle(self):
        self.aptrC = CircularAperture(self.coo, self.f * self.FWHM )
    def __setApertureAnnulus(self):
        self.aptrA = CircularAnnulus(self.coo, r_in = self.rIn, r_out = self.rOut)
    def __setRadii(self):
        self.rIn = self.FWHM*3
        self.rOut = (1.3) * self.rIn
    def __setAnnulusBackground(self):
        annulus_masks = self.aptrA.to_mask(method='center')
        annulus_data = annulus_masks.multiply(self.stdData)
        annulus_data_1d = annulus_data[annulus_masks.data > 0]
        _, bkg_median_sigclip, _ = sigma_clipped_stats(annulus_data_1d)
        self.bgMedian = bkg_median_sigclip
        
        phot = aptr.aperture_photometry(self.stdData, self.aptrC, method ='subpixel', error = self.errorData, subpixels = 5)
        phot['annulus_median'] = bkg_median_sigclip
        # flux from the background inside the aperture of the star :
        phot['aper_bkg'] = bkg_median_sigclip * self.aptrC.area
        # Now you can subtract the background flux from the aperture:
        self.aBG = float(phot['annulus_median'])
    def __setCcdMag(self):
        phot = aptr.aperture_photometry(self.stdData, self.aptrC, method = 'subpixel', error = self.errorData, subpixels = 5)
        power =  (phot['aperture_sum']/self.expTime) - (self.aBG/self.expTime)
        self.ccdMag =  float(-2.5*( np.log10(power) ) + 25)
    def __setMagErr(self):
        phot = aptr.aperture_photometry(np.square(self.errorData), self.aptrC)
        aptrErr = phot['aperture_sum'] + (self.aptrC.area**2 / self.aBG * self.bgMedian)
        self.magErr = 1.0857 * np.sqrt(aptrErr)/phot['aperture_sum']
    #==========================================================public methods
    def getFWHM(self):
        return self.FWHM
    def getApertureCircle(self):
        return self.aptrC
    def getBGMedian(self):
        return self.bgMedian
    def magnitude(self):
        return self.ccdMag
    def magnitudeErr(self):
        return self.magErr

##============================================================== 
def saveMags(filter, stdIdx, f, mag, err):
    priviousDir = os.getcwd()
    os.chdir(dirPC)
    if stdIdx == 0: ## create an empty file when writting the first stdstar 
        with open(filter+'.magnitudes', "w") as file:
            file.write('%f,%f,\n'%(mag,err))
    else:
        with open(filter+'.magnitudes', "a") as file:
            file.write('%f,%f,\n'%(mag,err))
    os.chdir(priviousDir)
    print(filter+'.magnitudes updated.................................')
            
##========================================= main
def plotErrorbar():
    fig, axs = plt.subplots(1,3,figsize = (15,5))
    PICK = 7
    for i in range(len(fitsFiles)):
        print('--------------------------------',filters[i],'--------------------------------')
        fitsHeader = getFitsHeader(fitsFiles[i])
        stdData  = getFitsData(fitsFiles[i])
        expTime = fitsHeader['EXPTIME']
        errorData = getPSError(filters[i],'SkyFlat')
        for j in range(len(coos)):## len(coos) = 3
            print('-----------',stdName[j],'-----------')
            coo = coos[j]
            mags = np.arange(len(apertureFactor), dtype ='f')
            errs = np.arange(len(apertureFactor), dtype ='f')
            sizes = np.arange(len(apertureFactor), dtype ='f')
            for f in range(1,len(apertureFactor)):
                s = Statistics(coos[j], stdData, errorData, expTime, f)
                sizes[f] = apertureFactor[f] * s.getFWHM()
                mags[f] = s.magnitude()
                errs[f] = s.magnitudeErr()
                aperture = s.getApertureCircle()
                if f == PICK:
                    saveMags(filters[i], j, f, mags[f], errs[f])
            print('mag : ', mags)
            print('err : ', errs)
            axs[i].errorbar(sizes, mags, errs, label = stdName[j], fmt='.', markersize='1')
            axs[i].set_title(filters[i])
            axs[i].legend()
            axs[i].set_xlim([2.5,17.5])
            axs[i].set_ylim([14,10.5])
            axs[i].set_xlabel('pixel')
            axs[i].set_ylabel('magnitude')
    plt.show()
plotErrorbar()
# Out:
# ['EFOSC.2001-01-03T08:55:18.187.fits', 'EFOSC.2001-01-03T08:56:03.899.fits', 'EFOSC.2001-01-03T08:54:27.270.fits']
#              filename             	EXPTIME	HIERARCH ESO INS FILT1 NAME	       OBJECT
# ----------------------------------	-------	---------------------------	--------------------
# EFOSC.2001-01-03T08:55:18.187.fits	4.9968 	           V#641           	PG-1323-086-phot-std
# EFOSC.2001-01-03T08:56:03.899.fits	4.9969 	           R#642           	PG-1323-086-phot-std
# EFOSC.2001-01-03T08:54:27.270.fits	9.9968 	           B#639           	PG-1323-086-phot-std
# -------------------------------- V#641 --------------------------------
# ----------- PG-1323-086   -----------
# V#641.magnitudes updated.................................
# mag :  [ 0.       12.770561 12.439629 12.182877 11.915217 11.649415 11.392761
#  11.152427]
# err :  [0.0000000e+00 4.1339351e-04 2.0800011e-04 1.3892615e-04 1.0425121e-04
#  8.3475781e-05 6.9626010e-05 5.9780010e-05]
# ----------- PG-1323-086 B -----------
# V#641.magnitudes updated.................................
# mag :  [ 0.        12.764504  12.381442  12.1405115 11.886696  11.632192
#  11.385119  11.152758 ]
# err :  [0.0000000e+00 4.1279476e-04 2.0729708e-04 1.3803483e-04 1.0359691e-04
#  8.2957537e-05 6.9211994e-05 5.9425685e-05]
# ----------- PG-1323-086 C -----------
# V#641.magnitudes updated.................................
# mag :  [ 0.       13.345449 12.862349 12.540888 12.221966 11.916926 11.63349
#  11.371603]
# err :  [0.0000000e+00 4.6004762e-04 2.3044768e-04 1.5415126e-04 1.1561120e-04
#  9.2553717e-05 7.7195116e-05 6.6264671e-05]
# -------------------------------- R#642 --------------------------------
# ----------- PG-1323-086   -----------
# R#642.magnitudes updated.................................
# mag :  [ 0.        12.774209  12.4261875 12.171429  11.902828  11.633875
#  11.3779125 11.137286 ]
# err :  [0.0000000e+00 3.5883035e-04 1.8007010e-04 1.2016536e-04 9.0161375e-05
#  7.2200994e-05 6.0202561e-05 5.1658481e-05]
# ----------- PG-1323-086 B -----------
# R#642.magnitudes updated.................................
# mag :  [ 0.       12.51624  11.998789 11.826215 11.644204 11.452574 11.257488
#  11.064733]
# err :  [0.0000000e+00 3.8006387e-04 1.9029518e-04 1.2657620e-04 9.4904841e-05
#  7.6019453e-05 6.3409942e-05 5.4444030e-05]
# ----------- PG-1323-086 C -----------
# R#642.magnitudes updated.................................
# mag :  [ 0.       12.911311 12.495894 12.227837 11.949483 11.675106 11.413356
#  11.16937 ]
# err :  [0.0000000e+00 3.6095636e-04 1.8015144e-04 1.2017445e-04 9.0143556e-05
#  7.2193441e-05 6.0263701e-05 5.1758874e-05]
# -------------------------------- B#639 --------------------------------
# ----------- PG-1323-086   -----------
# B#639.magnitudes updated.................................
# mag :  [ 0.        13.4057455 12.387118  12.010016  11.662603  11.338315
#  11.039532  10.768931 ]
# err :  [0.0000000e+00 3.7330986e-04 1.8734785e-04 1.2517620e-04 9.4035626e-05
#  7.5385433e-05 6.3005755e-05 5.4151020e-05]
# ----------- PG-1323-086 B -----------
# B#639.magnitudes updated.................................
# mag :  [ 0.        13.557788  12.818134  12.311924  11.8647585 11.473712
#  11.133524  10.832844 ]
# err :  [0.0000000e+00 3.7578927e-04 1.8712982e-04 1.2495142e-04 9.3751769e-05
#  7.5077325e-05 6.2752006e-05 5.3960681e-05]
# ----------- PG-1323-086 C -----------
# B#639.magnitudes updated.................................
# mag :  [ 0.       14.098548 13.064115 12.448596 11.941832 11.516    11.154456
#  10.84054 ]
# err :  [0.00000000e+00 3.60247213e-04 1.80563118e-04 1.20475015e-04
#  9.05495617e-05 7.25806167e-05 6.06701833e-05 5.21392285e-05]

# %%
import os
filters = ['V#641','R#642','B#639']

for f in filters:
    fileName = f+'.magnitudes'
    with open(fileName, "r") as file:
        lines = file.read().splitlines()   #list of strings
        print(f)
        print(lines)
# Out:
# V#641
# ['12.669344,0.007983,', '12.629570,0.007712,', '13.197060,0.011629,']
# R#642
# ['12.656260,0.009081,', '12.298160,0.006144,', '12.759604,0.009962,']
# B#639
# ['13.040272,0.006216,', '13.340097,0.008161,', '13.777802,0.012679,']

# %%
import os
print(os.getcwd())
# os.chdir('/..')
print(os.getcwd())
# Out:
# /Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3
# /Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3

# %% [markdown]
# ## Photometric Calibration
# * instrumental magnitude
# * zero-point magnitude

# %%
import os
import astropy.io.fits as fits
import dfitspy
import photutils.aperture as aptr
from photutils.aperture import CircularAperture
from photutils.centroids import centroid_quadratic
from photutils.profiles import RadialProfile
from photutils.centroids import centroid_quadratic
from photutils.profiles import RadialProfile
from photutils.aperture import CircularAperture
import photutils.aperture as aptr
from photutils.aperture import CircularAnnulus
from astropy.stats import sigma_clipped_stats
import numpy as np
##========================================= dirs
dirEx3 = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/'
dirSTD = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/STANDARD'
dirErr = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/PSError'
dirPC = '/Users/yhjo/Desktop/AstronomicalDataProcessing/Exercise/Ex3/PhotoCalibration'
filters =['V#641','R#642','B#639']
fileNames = {'V#641':'EFOSC.2001-01-03T08:55:18.187.fits',
             'R#642':'EFOSC.2001-01-03T08:56:03.899.fits',
             'B#639':'EFOSC.2001-01-03T08:54:27.270.fits'}
stdName = ['PG-1323-086', 'PG-1323-086 B', 'PG-1323-086 C']
extCoeff = [0.13, 0.09, 0.25]
coos = [np.array([733,451]),np.array([204,158]),np.array([231,589])]
apertureFactor = np.arange(0.5, 4.5, 0.5, dtype ='f')
##=================================================================

LandoltBands = ['V', 'B-V', 'U-B', 'V-R', 'R-I', 'V-I']
# PG 1323-086		13.481	-0.140	-0.681	-0.048	-0.078	-0.127
# PG 1323-086 B		13.406	0.761	0.265	0.426	0.407	0.833
# PG 1323-086 C		14.003	0.707	0.245	0.395	0.363	0.759
LandoltBand = [[13.481,	-0.140,	-0.681,	-0.048,	-0.078,	-0.127],
                [13.406,	0.761,	0.265,	0.426,	0.407,	0.833],
                [14.003,	0.707,	0.245,	0.395,	0.363,	0.759]]
#combination of 0, B, C with V, R, B
LandoltMag = np.zeros((3,3), dtype = 'f')
for i in range(len(LandoltBand)):
    LandoltMag[i][0] = LandoltBand[i][0]
    LandoltMag[i][1] = LandoltBand[i][0] - LandoltBand[i][3]
    LandoltMag[i][2] = LandoltBand[i][0] + LandoltBand[i][1]
print(LandoltMag)
##=================================================================
'''
@seeFits()
check the header
'''
def seeFits():
    prevDir = os.getcwd()
    os.chdir(dirSTD)
    fitsFiles = [m for m in os.listdir() if m.endswith('.fits')]
    for f in fitsFiles:
        header = fits.getheader(f)
        print(header)
    # stdFiles = dfitspy.dfitsort(fitsFiles)
    # dfitspy.dfitsort_view(stdFiles)
    os.chdir(prevDir)
#==================================================================  
'''
@getExpTime()
@returns exposure time
'''
def getExpTime(filter):
    fileName = fileNames[filter]
    return float(fits.getheader(fileName)['EXPTIME'])
#==================================================================  
'''
@getAirmass()
get airmass values from header of the .fits file of the standard stars in V, R, B filters
'''
def getAirmass(filter):
    prevDir = os.getcwd()
    os.chdir(dirSTD)
    fileName = fileNames[filter]
    am = float(fits.getheader(fileName)['HIERARCH ESO TEL AIRM START'])
    os.chdir(prevDir)
    return am

##=========================================
def getFitsData(fileName):
    fitsStdData = fits.getdata(fileName, header = False, dtype = 'f')
    stdData = fitsStdData[100:900,100:900]
    return stdData
##=========================================    
def getPSError(filter, type):
    previousDir = os.getcwd()
    pSError = [ [0]*800 for i in range(800) ]
    os.chdir(dirErr)
    fileName = filter+type+'.processed.error'
    if os.path.exists(fileName):
        with open(fileName, "r") as file:
            ##load data from file
            listOfLines = file.read().splitlines()   #list of strings
            for i in range(len(listOfLines)):
                line = listOfLines[i] #list of string, delimiter = ','
                listOfValues = line.split(',')
                for j in range(len(listOfValues)):
                    value = listOfValues[j]
                    if not value =='':
                        pSError[i][j] = float(value)
    os.chdir(previousDir)
    return pSError
#==================================================================
class Statistics:
    #=======================CTOR===================================\
    def __init__(self, coo, stdData, errorData, expTime, airmass, f, extC, landolt):
        self.prevDir = os.getcwd()
        os.chdir(dirPC)
        self.coo = coo
        self.stdData = stdData
        self.errorData = errorData
        self.expTime = expTime
        self.airmass = airmass
        self.extC = extC
        self.landolt = landolt
        self.f = f
        self.__setRadialProfile()
        self.FWHM = self.rp.gaussian_fwhm
        self.__setRadii()
        self.__setApertureCircle()
        self.__setCircularAptrPhot()
        self.__setApertureAnnulus()
        self.__setAnnulusBackground()
        self.__setCcdMag()
        self.__setMagErr()
        
        self._setZP()
        self.__setCountMag()
        self.__setCountMagErr()
    #=======================DTOR===================================\   
    def __del__(self):
        os.chdir(self.prevDir)
    #==========================================================private methods
    def __setRadialProfile(self):
        xycen = centroid_quadratic(self.stdData, xpeak = self.coo[0], ypeak = self.coo[1], fit_boxsize = 11, search_boxsize = 11)
        edge_radii = np.arange(4)
        rp = RadialProfile(self.stdData, xycen, edge_radii, mask=None)
        self.rp = rp
    def __setApertureCircle(self):
        self.aptrC = CircularAperture(self.coo, self.f * self.FWHM )
    def __setApertureAnnulus(self):
        self.aptrA = CircularAnnulus(self.coo, r_in = self.rIn, r_out = self.rOut)
    def __setRadii(self):
        self.rIn = self.FWHM*3
        self.rOut = (1.3) * self.rIn
    def __setCircularAptrPhot(self):
        self.phot = aptr.aperture_photometry(self.stdData, self.aptrC, method ='subpixel', error = self.errorData, subpixels = 5)
    def __setAnnulusBackground(self):
        annulus_masks = self.aptrA.to_mask(method='center')
        annulus_data = annulus_masks.multiply(self.stdData)
        annulus_data_1d = annulus_data[annulus_masks.data > 0]
        _, bkg_median_sigclip, _ = sigma_clipped_stats(annulus_data_1d)
        self.aBG = bkg_median_sigclip
        self.phot['annulus_median'] = self.aBG
        self.phot['aper_bkg'] = bkg_median_sigclip * self.aptrC.area
        self.corrAptrC = float(self.phot['aperture_sum']) - float(self.phot['aper_bkg'])
        
    def __setCcdMag(self):
        power = (self.phot['aperture_sum']/self.expTime) - (self.aBG/self.expTime)
        self.ccdMag =  float(-2.5*( np.log10(power) ) + 25)
        
    def __setMagErr(self):
        phot = aptr.aperture_photometry(np.square(self.errorData), self.aptrC)
        aptrErr = float(phot['aperture_sum']) + (self.aptrC.area**2 / self.aBG * self.aBG)
        self.magErr = 1.0857 * np.sqrt(aptrErr)/float(phot['aperture_sum'])
        
    def _setZP(self):
        zpCor = self.landolt-(self.ccdMag - self.extC*self.airmass)
        self.zp = 25 + zpCor
        
    def __setCountMag(self):
        power = float(self.phot['aperture_sum']*self.expTime)
        self.countMag = -2.5 * np.log(power) - self.extC*self.airmass
        
    def __setCountMagErr(self):
        self.countMagErr = 1.0857 * float(self.phot['aperture_sum']*self.expTime) - self.extC * self.airmass
    
    #==========================================================public methods
    def getFWHM(self):
        return self.FWHM
    def getBGMedian(self):
        return self.bgMedian
    def getCorrectedAptr(self):
        return self.corrAptrC
    def getCcdMag(self):
        return self.ccdMag
    def getMagErr(self):
        return self.magErr
    def getZP(self):
        return self.zp
    def getCountMag(self):
        return self.countMag
    def getCountMagErr(self):
        return self.countMagErr
    
#==================================================================     main
PICK = 7
os.chdir(dirPC)
for filter, fileName in fileNames.items():
    stdData = getFitsData(fileName)
    errorData = getPSError(filter, 'SkyFlat')
    expTime = getExpTime(filter)
    airmass = getAirmass(filter)
    iflt = filters.index(filter)
    extC = extCoeff[iflt]
    print('=========================',filter,'=========================')
    for star in stdName:
        print('-----------------',star,'-----------------')
        iStd = stdName.index(star)
        landMag = LandoltMag[iflt][iStd]
        s = Statistics(coos[iStd], stdData, errorData, expTime, airmass, PICK, extC, landMag)
        # print(s.FWHM)
        # print(s.ccdMag())
        corrAptr = s.getCorrectedAptr()
        ccdMag = s.getCcdMag()
        zp = s.getZP()
        magErr = s.getMagErr()
        countMag = s.getCountMag()
        countMagErr = s.getCountMagErr()
        print('ccdMag : ', ccdMag) 
        print('zp : ', zp)
        print('magErr : ', magErr)
    print()
# Out:
# [[13.481 13.529 13.341]
#  [13.406 12.98  14.167]
#  [14.003 13.608 14.71 ]]
# ========================= V#641 =========================
# ----------------- PG-1323-086 -----------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 206
#     204 iStd = stdName.index(star)
#     205 landMag = LandoltMag[iflt][iStd]
# --> 206 s = Statistics(coos[iStd], stdData, errorData, expTime, airmass, PICK, extC, landMag)
#     207 # print(s.FWHM)
#     208 # print(s.ccdMag())
#     209 corrAptr = s.getCorrectedAptr()
#
# Cell In[1], line 117, in Statistics.__init__(self, coo, stdData, errorData, expTime, airmass, f, extC, landolt)
#     115 self.__setApertureCircle()
#     116 self.__setCircularAptrPhot()
# --> 117 self.__setApertureAnnulus()
#     118 self.__setAnnulusBackground()
#     119 self.__setCcdMag()
#
# Cell In[1], line 137, in Statistics.__setApertureAnnulus(self)
#     136 def __setApertureAnnulus(self):
# --> 137     self.aptrA = CircularAnnulus(self.coo, r_in = self.rIn, r_out = self.rOut)
#
# NameError: name 'CircularAnnulus' is not defined
